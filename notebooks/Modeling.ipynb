# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split, cross_val_score

from sklearn.metrics import accuracy_score, f1_score
from feature_engine.encoding import OrdinalEncoder, OneHotEncoder
from feature_engine.transformation import YeoJohnsonTransformer
from sklearn.linear_model import LogisticRegression

# %%
pd.set_option("display.max_columns", 25)

# %%
data = pd.read_csv("../data/input_data/telco_customer_churn_1.csv")

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check           53.85       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
data.isnull().count()
# Out:
# customerID          6000
# gender              6000
# SeniorCitizen       6000
# Partner             6000
# Dependents          6000
# tenure              6000
# PhoneService        6000
# MultipleLines       6000
# InternetService     6000
# OnlineSecurity      6000
# OnlineBackup        6000
# DeviceProtection    6000
# TechSupport         6000
# StreamingTV         6000
# StreamingMovies     6000
# Contract            6000
# PaperlessBilling    6000
# PaymentMethod       6000
# MonthlyCharges      6000
# TotalCharges        6000
# Churn               6000
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        6000 non-null   object
#  1   gender            6000 non-null   object
#  2   SeniorCitizen     6000 non-null   int64
#  3   Partner           6000 non-null   object
#  4   Dependents        6000 non-null   object
#  5   tenure            6000 non-null   int64
#  6   PhoneService      6000 non-null   object
#  7   MultipleLines     6000 non-null   object
#  8   InternetService   6000 non-null   object
#  9   OnlineSecurity    6000 non-null   object
#  10  OnlineBackup      6000 non-null   object
#  11  DeviceProtection  6000 non-null   object
#  12  TechSupport       6000 non-null   object
#  13  StreamingTV       6000 non-null   object
#  14  StreamingMovies   6000 non-null   object
#  15  Contract          6000 non-null   object
#  16  PaperlessBilling  6000 non-null   object
#  17  PaymentMethod     6000 non-null   object
#  18  MonthlyCharges    6000 non-null   float64
#  19  TotalCharges      6000 non-null   object
#  20  Churn             6000 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 984.5+ KB

# %%
data['TotalCharges'].isnull().values.any()
# Out:
# False

# %%
nan_rows = data[data['TotalCharges'].isnull()]

# %%
data.isnull().T.any().T.sum()
# Out:
# 0

# %%
data.isnull().any().any()
# Out:
# False

# %%
data.isna().values.any()
# Out:
# False

# %% [markdown]
# ## Train - Test Split.

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop(['customerID', 'Churn'], axis=1),
                                data['Churn'], test_size=0.2, random_state=0)

# %% [markdown]
# ## Categorical and Numerical Features

# %%
cat_vars = [var for var in X_train.columns if X_train[var].dtype == 'object']
num_vars = [var for var in X_train.columns if var not in cat_vars]

# %%
cat_vars
# Out:
# ['gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'TotalCharges']

# %%
num_vars
# Out:
# ['SeniorCitizen', 'tenure', 'MonthlyCharges']

# %% [markdown]
# ## Categorical features

# %%
cat_vars_onehot = ['gender', 'Partner', 'Dependents', 'PhoneService', 'PaperlessBilling']
cat_vars_ordinal_arbitrary = ['MultipleLines', 'InternetService', 'OnlineSecurity',
    'OnlineBackup', 'DeviceProtection', 'TechSupport','StreamingTV', 'StreamingMovies',
    'Contract', 'PaymentMethod']

ordinal_encoder_arbitrary = OrdinalEncoder(encoding_method='arbitrary', variables=cat_vars_ordinal_arbitrary)
ordinal_encoder_arbitrary.fit(X_train, y_train)

onehot_encoder = OneHotEncoder(variables=cat_vars_onehot)
onehot_encoder.fit(X_train)
# Out:
# OneHotEncoder(variables=['gender', 'Partner', 'Dependents', 'PhoneService',
#                          'PaperlessBilling'])

# %%
X_train = ordinal_encoder_arbitrary.transform(X_train)
X_test =  ordinal_encoder_arbitrary.transform(X_test)
# Out:
# /Users/quangtn/opt/anaconda3/envs/fastapi_course/lib/python3.10/site-packages/feature_engine/encoding/base_encoder.py:260: UserWarning: During the encoding, NaN values were introduced in the feature(s) MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaymentMethod.
#   warnings.warn(

# %%
X_train = onehot_encoder.transform(X_train)
X_test  = onehot_encoder.transform(X_test)

# %% [markdown]
# ## Numerical Features

# %%
yeo_transformer = YeoJohnsonTransformer(variables=['TotalCharges'])

X_train = yeo_transformer.fit_transform(X_train)
X_test = yeo_transformer.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 3
#       1 yeo_transformer = YeoJohnsonTransformer(variables=['TotalCharges'])
# ----> 3 X_train = yeo_transformer.fit_transform(X_train)
#       4 X_test = yeo_transformer.transform(X_test)
#
# File ~/opt/anaconda3/envs/fastapi_course/lib/python3.10/site-packages/sklearn/utils/_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File ~/opt/anaconda3/envs/fastapi_course/lib/python3.10/site-packages/sklearn/base.py:1098, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1083         warnings.warn(
#    1084             (
#    1085                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)
#    1093             UserWarning,
#    1094         )
#    1096 if y is None:
#    1097     # fit method of arity 1 (unsupervised transformation)
# -> 1098     return self.fit(X, **fit_params).transform(X)
#    1099 else:
#    1100     # fit method of arity 2 (supervised transformation)
#    1101     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/opt/anaconda3/envs/fastapi_course/lib/python3.10/site-packages/feature_engine/transformation/yeojohnson.py:131, in YeoJohnsonTransformer.fit(self, X, y)
#     117 """
#     118 Learn the optimal lambda for the Yeo-Johnson transformation.
#     119
#    (...)
#     127     It is not needed in this transformer. You can pass y or None.
#     128 """
#     130 # check input dataframe
# --> 131 X = super().fit(X)
#     133 self.lambda_dict_ = {}
#     135 for var in self.variables_:
#
# File ~/opt/anaconda3/envs/fastapi_course/lib/python3.10/site-packages/feature_engine/_base_transformers/base_numerical.py:65, in BaseNumericalTransformer.fit(self, X)
#      63     self.variables_ = find_numerical_variables(X)
#      64 else:
# ---> 65     self.variables_ = check_numerical_variables(X, self.variables)
#      67 # check if dataset contains na or inf
#      68 _check_contains_na(X, self.variables_)
#
# File ~/opt/anaconda3/envs/fastapi_course/lib/python3.10/site-packages/feature_engine/variable_handling/check_variables.py:54, in check_numerical_variables(X, variables)
#      51     variables = [variables]
#      53 if len(X[variables].select_dtypes(exclude="number").columns) > 0:
# ---> 54     raise TypeError(
#      55         "Some of the variables are not numerical. Please cast them as "
#      56         "numerical before using this transformer."
#      57     )
#      59 return variables
#
# TypeError: Some of the variables are not numerical. Please cast them as numerical before using this transformer.
